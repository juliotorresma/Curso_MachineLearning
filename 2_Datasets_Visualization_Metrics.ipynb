# %% [markdown]
# <a href="https://colab.research.google.com/github/juliotorresma/Curso_MachineLearning/blob/main/2_Datasets_Visualization_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='blue'> Datasets, Visualization and Metrics </font>
# Todos los algoritmos de Machine Learning necesitan datos. Cuantos más datos, mejor aprendizaje. Los datos son **necesarios para el proceso de aprendizaje de algoritmos**. Un conjunto de datos representa toda la información que se puede procesar. Por ejemplo:
#
# 1.   1000 imágenes de caras, cada una etiquetada con el nombre de la persona.
# 2.   Base de datos del departamento comercial.
# 3.   Datos de una encuesta.
#
# Tradicionalmente, **la información se procesa previamente para tener una tabla con valores**, donde las columnas y filas representan las **características y las muestras**, respectivamente. Una característica, también llamada variable, representa una característica del objeto. Una muestra es un objeto concreto. Alguna nomenclatura clásica es:
#
# $ 𝑁 = $ Número de funciones
#
# $ 𝑀 = $ Número de muestras
#
# $ 𝑥_𝑖 = $ Característica $ i $ valores ($ i $ se aplica a todas las muestras)
#
# $ 𝑥 ^ {(𝑖)} = $ Muestra $ i $ valores ($ i $ se aplica a todas las funciones)
#
# $ 𝑦 ^ {(𝑖)} = $ Salida o etiqueta de la muestra $ i $
#
# $ 𝑥_𝑗 ^ {(𝑖)} = $ Muestra $ i $, característica $ j $
#
# Las siguientes imágenes muestran ejemplos de conjuntos de datos. El primero es un ejemplo de venta de viviendas y el segundo es un conjunto de datos que proviene de un problema de reconocimiento facial.

# %% [markdown]
# <img src="images/2_dataset_housesales.png">
# <img src="images/2_dataset_faces.png">

# %% [markdown]
# ## Tipos de funciones
#
# #### Clasificación
#
# - **Numérico**: Números, pueden ser enteros o continuos. Por ejemplo: edad, precio, temperatura.
# - **Ordinal**: Los valores de estas características no son números, pero sus valores tienen un orden específico. Por ejemplo: ¿Cómo te sientes hoy? Muy infeliz, infeliz, neutral, feliz o muy feliz. O académico: escuela primaria, secundaria, universidad, maestría, doctorado.
# - **Categórico o nominal**: Los valores de estas características representan categorías. No se pueden ordenar. Por ejemplo, género, color de cabello, lugar de nacimiento.

# %% [markdown]
# ## <font color = 'blue'> Funciones numéricas </font>
#
# <u> Algunas métricas que pueden resultar útiles para comprender las funciones numéricas son: </u>
#
# - Mínimo
# - Máximo
# - Rango: $ Máximo - mínimo $
# - Promedio o media: $ \ bar {x} = \ frac {\ sum_i x_i} {n} $
# - Mediana: si ordenamos las muestras, la mediana es el valor que se encuentra justo en el medio.
# - Varianza: población $ \ sigma ^ 2 = \ frac {\ sum_i (x_i- \ bar {x}) ^ 2} {n} $ muestra $ s ^ 2 = \ frac {\ sum_i (x_i- \ bar {x} ) ^ 2} {n-1} $
# - Desviación estándar: población $ \ sigma = \ sqrt {\ sigma ^ 2} $ muestra $ s = \ sqrt {s ^ 2} $. La desviación estándar puede verse como el promedio de todas las variaciones entre los datos y el promedio.
#
# - Cuartiles: divide el número de puntos de datos en cuatro partes. Los datos deben ordenarse de menor a mayor. El valor del 25% de los datos está por debajo del primer cuartil (Q1). El segundo cuartil (Q2) es la mediana de un conjunto de datos; por tanto, el 50% de los datos se encuentra por debajo de este punto. El valor del 75% de los datos está por debajo del primer cuartil (Q3).
#
# - Rango intercuartil: es útil para encontrar valores atípicos. $ IQR = Q_3- Q_1 $. Un valor atípico es una muestra cuyo valor $ x $ es $ x <Q_1-1.5 * IQR $ o $ x> Q_3 + 1.5 * IQR $.

# %% [markdown]
# <u> Para medir la dependencia entre dos características numéricas, podemos usar la covarianza y la correlación. </u>
#
# **_Covarianza_**
#
# Es un valor numérico que mide la dependencia lineal entre dos características numéricas.
#
# Población $ \ sigma_ {xy} = \ frac {\ sum_i (x_i- \ bar {x}) (y_i- \ bar {y})} {n} $ muestra $ \ sigma_ {xy} = \ frac {\ sum_i ( x_i- \ bar {x}) (y_i- \ bar {y})} {n-1} $
#
# Interpretación:
#
# - Un valor positivo indica que un aumento en una variable da como resultado un aumento en la otra variable.
# - Un valor negativo indica que un aumento en una variable da como resultado el cambio opuesto en la otra variable.
# - Un valor cercano a cero indica que no hay dependencia lineal. Sin embargo, podría haber una dependencia no lineal.
#
# [Ver imagen] (https://en.wikipedia.org/wiki/Covariance#/media/File:Covariance_trends.svg)
#
# El problema de la covarianza es que no tiene un rango limitado. Es difícil saber si un valor de covarianza de 343 representa una dependencia fuerte o débil.
#
# **_Correlación_**
#
# El coeficiente de correlación de Pearson, comúnmente llamado coeficiente de correlación, es un valor numérico que mide la relación lineal entre dos características numéricas. La diferencia con la covarianza es que tiene un rango limitado entre -1 y 1.
#
# Población $ r = \ frac {\ sigma_ {xy}} {\ sigma_x \ sigma_y} = \ frac {Cov (x, y)} {StdDev (x) StdDev (y)} $
#
# Muestra $ r = \ frac {\ sum_i (x_i- \ bar {x}) (y_i- \ bar {y})} {\ sqrt {\ sum_i (x_i - \ bar {x}) ^ 2} \ sqrt {\ sum_i (y_i - \ bar {y}) ^ 2}} $
#
# Interpretación:
#
# - El signo representa lo mismo que la covarianza.
# - Es un número entre -1 y 1
#     - Cuanto más cerca de -1 o 1, mayor será la dependencia lineal.
#     - Los valores cercanos a 0 indican que no hay dependencia lineal.
#
# [Ver imagen] (https://en.wikipedia.org/wiki/Correlation_and_dependence#/media/File:Correlation_examples2.svg)
#
# Desde mi perspectiva personal, es mucho mejor utilizar la correlación que la covarianza para medir la dependencia lineal entre características numéricas.

# %% [markdown]
# ## <font color = 'blue'> Funciones categóricas </font>
#
# <u> Algunas métricas que pueden resultar útiles para comprender las características categóricas son: </u>
#
# - Modo. Es el valor que aparece con mayor frecuencia.
#
# **_Entropía_**
#
# La entropía, también llamada entropía de la información o entropía de Shannon, mide la **sorpresa** o el **caos** en los valores de una variable. Formalmente, mide la uniformidad de la variable. Se puede calcular de la siguiente manera:
#
# $ H (X) = - \ sum_x P (x) log_2 P (x) $
#
# ![2_entropy.png](data:image/png;base64,...)
#
# El problema es que no existe un valor máximo para la entropía. Para cada variable, el valor máximo es $ H (X) = - log_2 \ left (\ frac {1} {No.categories} \ right) $

# %% [markdown]
# <u> Los gráficos que podemos usar para visualizar características categóricas son: </u>
#
# - Parcela de barras. Cada longitud de barra representa la frecuencia de cada categoría. [Véanse los Ejemplos] (https://www.google.com/search?q=bar+plot&tbm=isch&ved=2ahUKEwiX3_bV_NDuAhUMNK0KHaNaD6kQ2-cCegQIABAA&oq=bar+plot&gs_lcp=CgNpbWcQA1DEjgdY9JUHYPOWB2gAcAB4AIABAIgBAJIBAJgBAKABAaoBC2d3cy13aXotaW1nwAEB&sclient=img&ei=REwcYJetFIzotAWjtb3ICg&bih=454&biw=1093&rlz=1C1SQJL_enMX896MX896&safe=strict).
#
# - Gráfico circular. Cada sección representa la proporción de elementos en cada categoría. [Véanse los Ejemplos] (https://www.google.com/search?q=pie+plot&safe=strict&rlz=1C1SQJL_enMX896MX896&sxsrf=ALeKk02sIRqsG9-mh48NzjqKRhFfZDPRRQ:1612467266079&source=lnms&tbm=isch&sa=X&ved=2ahUKEwiH4uzU_NDuAhVJip4KHQd7A0wQ_AUoAXoECAMQAw&biw=1093&bih=454&dpr=1.25w). Tenga cuidado porque si los gráficos circulares se representan con diferentes efectos, pueden causar malentendidos. [Ver ejemplo] (https://www.indiabix.com/data-interpretation/pie-charts/).
#
# - Gráfico circular rectangular. Es similar a un gráfico circular, pero usamos rectángulos en lugar de un círculo. [Ver ejemplos] (https://www.google.com/search?q=rectangular+pie+chart&tbm=isch&ved=2ahUKEwjgkZmk_tDuAhWGa6wKHQGfCg8Q2-cCegQIABAA&oq=rectangular+pie+chart&gs_lcp=CgNpbWcQAzIFCAAQsQMyBQgAELEDMgUIABCxAzICCAAyAggAMgIIADICCAAyAggAMgIIADICCAA6BAgjECc6BAgAEEM6CAgAELEDEIMBUIU3WKl6YL57aABwAHgAgAHcA4gB8yCSAQcyLTMuNi4zmAEAoAEBqgELZ3dzLXdpei1pbWfAAQE&sclient=img&ei=9E0cYODHN4bXsQWBvqp4&bih=454&biw=1093&rlz=1C1SQJL_enMX896MX896&safe=strict ).

# %% [markdown]
# <u>The graphs that we can use to visualize numeric features are:</u>
#
# - Histogram (1 feature). It is similar to a bar plot, but the difference is that a bar plot is used for categorical features and histograms for numeric features. It means the bars' ranges represent values, they are ordered, and we can change the width or number of bars. It is very useful for recognizing the distribution of the variables or if it has one or two modes. [See examples](https://www.google.com/search?q=histograms&safe=strict&rlz=1C1SQJL_enMX896MX896&sxsrf=ALeKk01wtRX3bg52N0to6JBMentknDEFpA:1608809662185&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjhxLODw-btAhURQq0KHVvKDNYQ_AUoAXoECAMQAw).
#
# - Boxplot (1 feature). It represents the distribution of a numerical feature based on quartiles. It is very useful to recognize outliers. The box width represents how sparse the samples are. [See examples](https://www.google.com/search?q=boxplot&safe=strict&rlz=1C1SQJL_enMX896MX896&sxsrf=ALeKk01yC2D3sw34EshMLIlIHz0mrQvdOQ:1608810342412&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjwlOHHxebtAhUFQK0KHQFkCK0Q_AUoAXoECA8QAw).
#
# - Scatter plot (2 features). It is really useful for understand the relationship between two numerical features. [See examples](https://www.google.com/search?q=scatter+plot&safe=strict&rlz=1C1SQJL_enMX896MX896&sxsrf=ALeKk01SKMKoHvnFX1aCJjSGS3I8LiCNnQ:1608810420509&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi14v_sxebtAhWOQs0KHfh3ARgQ_AUoAXoECAIQAw&biw=1093&bih=454).
#
# - Bubble plot (3 features). It is similar to a scatter plot, but using colors and sizes it can represent more than two features. [See examples](https://www.google.com/search?q=bubble+plot&tbm=isch&ved=2ahUKEwjKja3wxebtAhXXa6wKHXKTA5oQ2-cCegQIABAA&oq=bubble+plot&gs_lcp=CgNpbWcQA1DZ3wFYlukBYMTqAWgAcAB4AIABAIgBAJIBAJgBAKABAaoBC2d3cy13aXotaW1nwAEB&sclient=img&ei=u3_kX4rEINfXsQXypo7QCQ&bih=454&biw=1093&rlz=1C1SQJL_enMX896MX896&safe=strict).
